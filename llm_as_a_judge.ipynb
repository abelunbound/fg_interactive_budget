# %%
import pandas as pd
import os
from dotenv import load_dotenv

# %%
# Mandate data ingestion
input_path_csv = "data/inputs/combine_mandate_581_891.csv"

mandate_df_581_891 = pd.read_csv(input_path_csv)

# %%
print(len(mandate_df_581_891))
# Out:
# 296

# %%
mandate_df_581_891.head()
# Out:
#     mda_code                                           mda_name  \
# 0  521014001  # NIGERIAN FEDERAL AGENCY MANDATES: AGENCIES 5...
# 1  535021001  582. NATIONAL AGENCY FOR GREAT GREEN WALL (NAGGW)
# 2  111057001  583. NATIONAL AGENCY FOR SCIENCE AND ENGINEERI...
# 3  161012001  584. NATIONAL AGENCY FOR THE CONTROL OF AIDS (...
# 4  215018001  585. NATIONAL AGRICULTURAL EXTENSION AND RESEA...
#
#                                  mandate_description
# 0  **MDA Code:** 521014001\n\nNational Agency for...
# 1  National Agency for Great Green Wall is federa...
# 2  National Agency for Science and Engineering In...
# 3  National Agency for the Control of AIDS (NACA)...
# 4  National Agricultural Extension and Research L...

# %%
mandate_df_581_891.dtypes
# Out:
# mda_code                int64
# mda_name               object
# mandate_description    object
# dtype: object

# %%
ergp_budget_with_mda_path = "data/outputs/ergp_budget_with_mda_no_duplicates.csv"
budget_df = pd.read_csv(ergp_budget_with_mda_path)

# %%
# Drop the first column by index 
# (remove Unnamed: 0)

budget_df = budget_df.drop('Unnamed: 0', axis=1)

# %%
print(len(budget_df))
# Out:
# 27538

# %%
budget_df.head()
# Out:
#            code                                     ergp_line_item   status  \
# 0  ERGP30102445                     UPGRADE OF STATE HOUSE LIBRARY  ONGOING
# 1  ERGP30114992  DIGITAL MEDICAL REFERENCES FOR THE STATE HOUSE...  ONGOING
# 2   ERGP6101477  REHABILITATION OF ANIMAL ENCLOSURE/PROCUREMENT...  ONGOING
# 3   ERGP6114996  CONVERSION/UPGRADE OF VILLA RANCH AND CONSTRUC...  ONGOING
# 4   ERGP6114997  PURCHASE OF PLANT NURSERY EQUIPMENT FOR PRODUC...  ONGOING
#
#        amount   mda_code               agency  mother_ministry
# 0   9028123.0  111001001  STATE HOUSE - HQTRS              NaN
# 1   3219762.0  111001001  STATE HOUSE - HQTRS              NaN
# 2  21850216.0  111001001  STATE HOUSE - HQTRS              NaN
# 3  38466135.0  111001001  STATE HOUSE - HQTRS              NaN
# 4  26912671.0  111001001  STATE HOUSE - HQTRS              NaN

# %%
budget_df.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount             float64
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
# Remove commas and convert to float
budget_df['amount'] = budget_df['amount'].str.replace(',', '').astype('float64')

# %%
budget_df.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount             float64
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
mda_list_581_891 = [
    521014001,
    535021001,
    111057001,
    161012001,
    215018001,
    215061001,
    215035001,
    111056001,
    215051001,
    265003001,
    521005001,
    222004001,
    535022001,
    228008001,
    521047001,
    517030001,
    517029001,
    161021001,
    123008001,
    238004001,
    517013001,
    252048001,
    517021024,
    521026012,
    265008001,
    123006001,
    517018017,
    517004001,
    517006001,
    125004001,
    517018019,
    517021064,
    517007001,
    254012001,
    255003001,
    215008001,
    157002002,
    157003001,
    157003002,
    233008001,
    318001001,
    517008001,
    164004001,
    164003001,
    517021025,
    164002001,
    233005001,
    521048002,
    521048003,
    521048001,
    228043001,
    535015001,
    517024001,
    123031017,
    521027063,
    521027014,
    521027015,
    535002001,
    161013001,
    161024001,
    521022001,
    231010001,
    521003001,
    227004001,
    228044001,
    215007001,
    231003001,
    521029001,
    521029014,
    521029005,
    521029008,
    521029011,
    521029009,
    521029003,
    521029006,
    521029007,
    521029010,
    521029004,
    521029013,
    521029016,
    521029002,
    155004001,
    160001001,
    161008001,
    157004001,
    111062001,
    161009001,
    123005001,
    451002001,
    252044001,
    215053001,
    230004001,
    111048001,
    521027047,
    161015001,
    156003001,
    124002001,
    231011001,
    111011001,
    513021002,
    252002001,
    124003001,
    228051001,
    513021003,
    326005001,
    228050001,
    242001001,
    157001001,
    554009001,
    517032001,
    554003001,
    228005001,
    513001001,
    233013001,
    233004001,
    521027016,
    517017001,
    256007001,
    256008001,
    517020001,
    517021057,
    265002001,
    256010001,
    252049001,
    555002001,
    554006001,
    228079001,
    116006001,
    231005001,
    222008001,
    222006001,
    256002001,
    256003001,
    111009002,
    238002001,
    254006001,
    228045001,
    265007001,
    119008001,
    521032001,
    257006001,
    215037001,
    229002001,
    222030001,
    326002001,
    230002001,
    451003001,
    451007001,
    222002001,
    111001001,
    111001007,
    111001006,
    111001002,
    111001003,
    157002003,
    517026102,
    234006001,
    222014001,
    517014001,
    119002001,
    116022001,
    231020001,
    517028001,
    517003001,
    521026001,
    517021010,
    554002001,
    535016001,
    517009001,
    521027039,
    521048004,
    256006001,
    161014001,
    521002001,
    215011001,
    521049001,
    326007001,
    116004002,
    161005001,
    254004001,
    521051001,
    521031001,
    517021028,
    517018024,
    123031011,
    215004001,
    157005001,
    228033001,
    514002001,
    215005001,
    554007001,
    517033001,
    517016001,
    256004001,
    517011001,
    554005001,
    256005001,
    111058001,
    157006001,
    157007001,
    116007001,
    227005001,
    326009001,
    521027040,
    517012001,
    116004001,
    229003001,
    230006001,
    123003001,
    255002001,
    119001002,
    156006001,
    111006001,
    521026014,
    517021022,
    521036001,
    451008001,
    554004001,
    451005001,
    521011001,
    517021005,
    521026015,
    517021006,
    521026005,
    517021008,
    521026010,
    517021001,
    517021009,
    521026007,
    517021007,
    517021002,
    517021021,
    521026011,
    521026004,
    517021003,
    517021014,
    521026009,
    517021016,
    517021020,
    521027002,
    252047001,
    252050001,
    517021042,
    228004001,
    232009001,
    222031001,
    155002001,
    123009001,
    124004001,
    215050001,
    116005001,
    116009001,
    116003001,
    517021044,
    228041001,
    220023001,
    230003001,
    326010001,
    521026006,
    220007001,
    111001004,
    111001005,
    125001001,
    215055001,
    554008001,
    253016001,
    252045001,
    222013001,
    535009001,
    521009001,
    535004001,
    220015001,
    119009122,
    232003001,
    521012001,
    521029012,
    161019001,
    228042001,
    145001001,
    125006001,
    517026101,
    521006001,
    521026023,
    228078001,
    326008001,
    234007001,
    246001001,
    215016001,
    161001001,
    238005002,
    161018001,
    228003001,
    222027001,
    252046001,
    257004001,
    451006001,
   
]

# %%
budget_df_mda_581_891= budget_df[budget_df['mda_code'].isin(mda_list_581_891)]

# %%
print(len(budget_df_mda_581_891))
# Out:
# 10747

# %%
budget_df_mda_581_891.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount             float64
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
# code	ergp_line_item	mda	amount	similarity_score	mandate_deviation_score

# %% [markdown]
# ### LLM-AS-JUDGE:

# %%
# =============================================================================
# LLM-AS-JUDGE: CLAUDE API IMPLEMENTATION
# =============================================================================

import anthropic
import pandas as pd
import time
from typing import Optional


# =============================================================================
# CONFIGURATION
# =============================================================================
ANTHROPIC_API_KEY = os.getenv("CLAUDE_API_KEY")
MODEL_NAME = "claude-sonnet-4-20250514"  # Good balance of speed/cost/quality
MAX_RETRIES = 3
RETRY_DELAY = 2  # seconds

# %%
# =============================================================================
# CORE FUNCTIONS
# =============================================================================

def create_client(api_key: str = ANTHROPIC_API_KEY) -> anthropic.Anthropic:
    """Create Anthropic client."""
    return anthropic.Anthropic(api_key=api_key)


def judge_alignment(
    client: anthropic.Anthropic,
    line_item: str,
    agency: str,
    mandate: str
) -> dict:
    """
    Use Claude to judge if budget item aligns with agency mandate.
    
    Returns:
        dict with keys: alignment, confidence, reason
    """
    prompt = f"""You are an auditor checking if Nigerian government budget items align with agency mandates.

    AGENCY: {agency}

    AGENCY MANDATE: {mandate}

    BUDGET LINE ITEM: {line_item}

    Does this budget item fall within the agency's mandate?

    Respond in EXACTLY this format (no other text):
    ALIGNMENT: YES or PARTIAL or NO
    CONFIDENCE: HIGH or MEDIUM or LOW
    REASON: (one sentence explanation)"""

    for attempt in range(MAX_RETRIES):
        try:
            response = client.messages.create(
                model=MODEL_NAME,
                max_tokens=150,
                messages=[
                    {"role": "user", "content": prompt}
                ]
            )
            
            result_text = response.content[0].text
            return parse_llm_response(result_text)
            
        except Exception as e:
            if attempt < MAX_RETRIES - 1:
                print(f"   Retry {attempt + 1}/{MAX_RETRIES} after error: {e}")
                time.sleep(RETRY_DELAY)
            else:
                print(f"   Failed after {MAX_RETRIES} attempts: {e}")
                return {
                    "alignment": "ERROR",
                    "confidence": "UNKNOWN",
                    "reason": str(e)
                }


def parse_llm_response(response: str) -> dict:
    """Parse the structured LLM response."""
    result = {
        "alignment": "UNKNOWN",
        "confidence": "UNKNOWN",
        "reason": ""
    }
    
    lines = response.strip().split("\n")
    
    for line in lines:
        line = line.strip()
        if line.upper().startswith("ALIGNMENT:"):
            value = line.split(":", 1)[1].strip().upper()
            if value in ["YES", "PARTIAL", "NO"]:
                result["alignment"] = value
        elif line.upper().startswith("CONFIDENCE:"):
            value = line.split(":", 1)[1].strip().upper()
            if value in ["HIGH", "MEDIUM", "LOW"]:
                result["confidence"] = value
        elif line.upper().startswith("REASON:"):
            result["reason"] = line.split(":", 1)[1].strip()
    
    return result


def compute_deviation_score(alignment: str, confidence: str) -> float:
    """
    Convert alignment + confidence to a deviation score (0-100).
    
    Higher score = more likely outside mandate = higher audit priority.
    """
    alignment_scores = {
        "YES": 0,
        "PARTIAL": 50,
        "NO": 100,
        "UNKNOWN": 50,
        "ERROR": 50
    }
    
    confidence_adjustments = {
        "HIGH": 0,
        "MEDIUM": 5,
        "LOW": 10,
        "UNKNOWN": 10
    }
    
    base_score = alignment_scores.get(alignment, 50)
    adjustment = confidence_adjustments.get(confidence, 10)
    
    # For YES: add adjustment (less confident YES = slightly higher deviation)
    # For NO: subtract adjustment (less confident NO = slightly lower deviation)
    if alignment == "YES":
        return min(base_score + adjustment, 100)
    elif alignment == "NO":
        return max(base_score - adjustment, 0)
    else:
        return base_score


# =============================================================================
# MAIN ANALYSIS FUNCTION
# =============================================================================

def analyze_budget_mandate_alignment_llm(
    budget_df: pd.DataFrame,
    mandate_df: pd.DataFrame,
    api_key: str = ANTHROPIC_API_KEY,
    progress_interval: int = 10
) -> pd.DataFrame:
    """
    Analyze alignment between budget items and agency mandates using Claude.
    
    Args:
        budget_df: DataFrame with columns [code, ergp_line_item, mda_code, agency, mother_ministry, amount]
        mandate_df: DataFrame with columns [mda_code, mda_name, mandate_description]
        api_key: Anthropic API key
        progress_interval: Print progress every N items
        
    Returns:
        DataFrame with alignment results
    """
    # Create client
    client = create_client(api_key)
    
    # Create mandate lookup by mda_code
    mandate_lookup = dict(zip(mandate_df["mda_code"], mandate_df["mandate_description"]))
    
    results = []
    total_items = len(budget_df)
    
    print(f"Analyzing {total_items} budget items with Claude...")
    print(f"Estimated time: {total_items * 1.5 / 60:.1f} - {total_items * 2.5 / 60:.1f} minutes")
    print("=" * 60)
    
    start_time = time.time()
    
    for i, (_, row) in enumerate(budget_df.iterrows()):
        mda_code = row["mda_code"]
        line_item = row["ergp_line_item"]
        agency = row["agency"]
        mandate = mandate_lookup.get(mda_code, "")
        
        if mandate:
            judgement = judge_alignment(client, line_item, agency, mandate)
        else:
            judgement = {
                "alignment": "UNKNOWN",
                "confidence": "UNKNOWN",
                "reason": "No mandate found for this agency"
            }
        
        deviation = compute_deviation_score(
            judgement["alignment"], 
            judgement["confidence"]
        )
        
        results.append({
            "code": row["code"],
            "ergp_line_item": row["ergp_line_item"],
            "mda_code": row["mda_code"],
            "agency": row["agency"],
            "mother_ministry": row["mother_ministry"],
            "amount": row["amount"],
            "alignment": judgement["alignment"],
            "confidence": judgement["confidence"],
            "reason": judgement["reason"],
            "mandate_deviation_score": deviation
        })
        
        # Progress update
        if (i + 1) % progress_interval == 0 or (i + 1) == total_items:
            elapsed = time.time() - start_time
            rate = (i + 1) / elapsed
            remaining = (total_items - i - 1) / rate if rate > 0 else 0
            print(f"   Processed {i + 1}/{total_items} ({(i+1)/total_items*100:.1f}%) | "
                  f"Elapsed: {elapsed/60:.1f}min | Remaining: {remaining/60:.1f}min")
    
    print("=" * 60)
    print("Analysis complete.")
    
    return pd.DataFrame(results)

# %%
# =============================================================================
# OUTPUT & REPORTING
# =============================================================================

def print_summary_llm(result_df: pd.DataFrame) -> None:
    """Print summary statistics for LLM analysis."""
    print("\n" + "=" * 80)
    print("SUMMARY: LLM-AS-JUDGE ANALYSIS")
    print("=" * 80)
    
    total_items = len(result_df)
    total_amount = result_df["amount"].sum()
    
    # Alignment distribution
    alignment_counts = result_df["alignment"].value_counts()
    
    print(f"\nTotal Budget Items: {total_items}")
    print(f"Total Budget Amount: ₦{total_amount:,.0f}")
    
    print(f"\nAlignment Distribution:")
    for alignment, count in alignment_counts.items():
        pct = count / total_items * 100
        amount = result_df[result_df["alignment"] == alignment]["amount"].sum()
        print(f"   {alignment}: {count} items ({pct:.1f}%) | ₦{amount:,.0f}")
    
    # Flagged items (NO alignment)
    flagged = result_df[result_df["alignment"] == "NO"]
    print(f"\n🚨 Items flagged as NOT aligned: {len(flagged)}")
    print(f"   Flagged amount: ₦{flagged['amount'].sum():,.0f}")


def print_flagged_items_llm(result_df: pd.DataFrame, top_n: int = 20) -> None:
    """Print items flagged as not aligned."""
    flagged = result_df[result_df["alignment"] == "NO"].sort_values(
        "amount", ascending=False
    ).head(top_n)
    
    if len(flagged) == 0:
        print("\n✅ No items flagged as misaligned!")
        return
    
    print("\n" + "=" * 100)
    print(f"TOP {top_n} FLAGGED ITEMS (NOT ALIGNED)")
    print("=" * 100)
    
    for _, row in flagged.iterrows():
        print(f"\n🚨 {row['code']}: {row['ergp_line_item'][:60]}...")
        print(f"   Agency: {row['agency']}")
        print(f"   Amount: ₦{row['amount']:,.0f}")
        print(f"   Confidence: {row['confidence']}")
        print(f"   Reason: {row['reason']}")

# %%
# =============================================================================
#  USAGE 
# =============================================================================


# Example usage (replace with your actual data)

# 1. Set your API key
api_key = ANTHROPIC_API_KEY

# 2. Run analysis
result_df = analyze_budget_mandate_alignment_llm(
    budget_df=budget_df_mda_581_891,
    mandate_df=mandate_df_581_891,
    api_key=api_key,
    progress_interval=10
)
# Out:
# Analyzing 10747 budget items with Claude...
# Estimated time: 268.7 - 447.8 minutes
# ...
#    Processed 10/10747 (0.1%) | Elapsed: 0.5min | Remaining: 588.3min
#    Processed 20/10747 (0.2%) | Elapsed: 1.0min | Remaining: 553.4min
#    Processed 30/10747 (0.3%) | Elapsed: 1.6min | Remaining: 557.0min
#    Processed 40/10747 (0.4%) | Elapsed: 2.0min | Remaining: 547.2min
#    Processed 50/10747 (0.5%) | Elapsed: 5.5min | Remaining: 1183.4min
#    Processed 60/10747 (0.6%) | Elapsed: 6.0min | Remaining: 1069.1min
#    Processed 70/10747 (0.7%) | Elapsed: 6.5min | Remaining: 992.6min
#    Processed 80/10747 (0.7%) | Elapsed: 7.0min | Remaining: 932.9min
#    Processed 90/10747 (0.8%) | Elapsed: 7.5min | Remaining: 888.7min
#    Processed 100/10747 (0.9%) | Elapsed: 8.0min | Remaining: 852.2min
#    Processed 110/10747 (1.0%) | Elapsed: 8.5min | Remaining: 820.3min
#    Processed 120/10747 (1.1%) | Elapsed: 9.0min | Remaining: 798.4min
# ...

# %%
print(len(result_df))
# Out:
# 10747

# %%
result_df.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
result_df.dtypes
# Out:
# code                        object
# ergp_line_item              object
# mda_code                     int64
# agency                      object
# mother_ministry            float64
# amount                     float64
# alignment                   object
# confidence                  object
# reason                      object
# mandate_deviation_score      int64
# dtype: object

# %%
# 3. View results
print_summary_llm(result_df)
print_flagged_items_llm(result_df)

# 4. Export
result_df.to_csv("llm_alignment_results_581_891.csv", index=False)

pass
# Out:
# ...
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ...
#
# Total Budget Items: 10747
# Total Budget Amount: ₦13,048,770,777,241
#
# Alignment Distribution:
#    YES: 5027 items (46.8%) | ₦7,806,341,776,821
#    NO: 3904 items (36.3%) | ₦2,447,618,379,686
#    PARTIAL: 1814 items (16.9%) | ₦2,794,775,620,734
#    ERROR: 2 items (0.0%) | ₦35,000,000
#
# 🚨 Items flagged as NOT aligned: 3904
#    Flagged amount: ₦2,447,618,379,686
#
# ...
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ...
#
# 🚨 ERGP16210669: MILITARY PENSIONS - MILITARY PENSION...
#    Agency: SERVICE WIDE VOTE
#    Amount: ₦239,522,931,359
#    Confidence: HIGH
#    Reason: Military pensions are specific statutory obligations that should be funded through dedicated pension agencies or the military's own budget allocation, not through the Service Wide Vote which is meant for government-wide services, contingencies, and cross-cutting needs.
#
# 🚨 ERGP25234023: NIGERIA INTELLIGENCE AGENCY (NIA) HOSPITAL
# ...
#    Agency: SERVICE WIDE VOTE
# ...

# %%
result_df.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
print(len(result_df))
# Out:
# 5686

# %%
result_df.dtypes
# Out:
# code                        object
# ergp_line_item              object
# mda_code                     int64
# agency                      object
# mother_ministry            float64
# amount                     float64
# alignment                   object
# confidence                  object
# reason                      object
# mandate_deviation_score      int64
# dtype: object

# %%
# stack 1 - 380, 381 - 580 and 581 - 891.

mandate_deviation_output_path_1_380 = "data/outputs/mandate_deviation/combined_llm_alignment_results_1_to_380.csv"
result_df_1_380= pd.read_csv(mandate_deviation_output_path_1_380)

mandate_deviation_output_path_381_580 = "data/outputs/mandate_deviation/llm_alignment_results_381_580.csv"
result_df_381_580= pd.read_csv(mandate_deviation_output_path_381_580)

mandate_deviation_output_path_581_891 = "data/outputs/mandate_deviation/llm_alignment_results_581_891.csv"
result_df_581_891= pd.read_csv(mandate_deviation_output_path_581_891)

# Merge vertically (stack rows)
merged_mandate_deviation_for_mdas_1_580_df = pd.concat([result_df_1_380, result_df_381_580], ignore_index=True)
merged_mandate_deviation_for_mdas_1_891_df = pd.concat([merged_mandate_deviation_for_mdas_1_580_df, result_df_581_891], ignore_index=True)

# %%
merged_mandate_deviation_for_mdas_1_891_df.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# ...

# %%
print(len(merged_mandate_deviation_for_mdas_1_891_df))
# Out:
# 20391

# %%
cols_mandate_deviation = [
    'code', 'ergp_line_item',
    # 'mda_code', 'agency', 'mother_ministry', 'amount',
    # 'alignment', 'confidence', 'reason','mandate_deviation_score'
]

mdas_1_891_no_duplicates = merged_mandate_deviation_for_mdas_1_891_df.drop_duplicates(subset=cols_mandate_deviation)
# mdas_1_891_no_duplicates.reset_index(drop=True, inplace=True)

# %%
mdas_1_891_no_duplicates.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
print(len(mdas_1_891_no_duplicates))
# Out:
# 20391

# %%
# export combined csv
mdas_1_891_no_duplicates.to_csv("combined_llm_alignment_results_1_891.csv", index=False)

# %%
# Group by mda_code
budget_padding_summary_df = mdas_1_891_no_duplicates.groupby('mda_code').apply(
    lambda x: pd.Series({
        'flagged_amount': x[x['alignment'] == 'NO']['amount'].sum(),  # (1) sum where alignment is 'NO'
        'total_amount': x['amount'].sum(),  # (2) sum all amounts for the agency
        'agency': x['agency'].iloc[0]  # keep agency name
    })
).reset_index(drop=True)

# (3) Calculate ratio
budget_padding_summary_df['flagged_ratio'] = budget_padding_summary_df['flagged_amount'] / budget_padding_summary_df['total_amount']
# Out:
# /var/folders/jj/66ym3p5j62s0g7zqbfvfg40c0000gn/T/ipykernel_6372/1932823915.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   budget_padding_summary_df = mdas_1_891_no_duplicates.groupby('mda_code').apply(

# %%
budget_padding_summary_df.head()
# Out:
#    flagged_amount  total_amount  \
# 0      26912511.0  3.052168e+10
# 1     134257312.0  7.713732e+08
# 2      79833217.0  6.413852e+08
# 3             0.0  3.456059e+08
# 4             0.0  3.458174e+08
#
#                                           agency  flagged_ratio
# 0                            STATE HOUSE - HQTRS       0.000882
# 1             STATE HOUSE OPERATIONS - PRESIDENT       0.174050
# 2        STATE HOUSE OPERATIONS - VICE PRESIDENT       0.124470
# 3  OFFICE OF THE CHIEF OF STAFF TO THE PRESIDENT       0.000000
# 4                     STATE HOUSE MEDICAL CENTRE       0.000000

# %%
budget_padding_summary_df['flagged_amount'] = budget_padding_summary_df['flagged_amount'].astype('int64')
# budget_padding_summary_df['flagged_amount'] = budget_padding_summary_df['flagged_amount'].apply(lambda x: f"{x:,.2f}")


budget_padding_summary_df['total_amount'] = budget_padding_summary_df['total_amount'].astype('int64')
# budget_padding_summary_df['total_amount'] = budget_padding_summary_df['total_amount'].apply(lambda x: f"{x:,.2f}")


budget_padding_summary_df['flagged_percent'] = budget_padding_summary_df['flagged_ratio'].apply(lambda x: f"{x:.2%}")

# %%
budget_padding_summary_df = budget_padding_summary_df.sort_values('flagged_ratio', ascending=False)

# %%
budget_padding_summary_df.head(100)
# Out:
#      flagged_amount  total_amount  \
# 7       14000000000   14392470828
# 149      9640963623    9972994978
# 294     31344312730   32665455192
# 219     53364452386   56064114604
# 241     31066490000   33373845874
# ..              ...           ...
# 157      3630200000   10150117687
# 545       440086111    1241163447
# 257      6600552566   19112986739
# 185       270007678     814064101
# 528       210000000     635664834
#
#                                                 agency  flagged_ratio  \
# 7                   BUREAU OF PUBLIC ENTERPRISES (BPE)       0.972731
# 149                       INDUSTRIAL ARBITRATION PANEL       0.966707
# 294       NATIONAL UNIVERSITIES COMMISSION SECRETARIAT       0.959555
# 219  NIGERIAN INSTITUTE FOR OCEANOGRAPHY AND MARINE...       0.951847
# 241  FEDERAL COLLEGE OF VETERINARY AND MEDICAL LABO...       0.930863
# ..                                                 ...            ...
# ...

# %%
# 3. View results
print_summary_llm(result_df)
print_flagged_items_llm(result_df)

# 4. Export
result_df.to_csv("llm_alignment_results_51_to_200.csv", index=False)

pass
# Out:
# ...
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ...
#
# Total Budget Items: 5686
# Total Budget Amount: ₦2,210,874,466,149
#
# Alignment Distribution:
#    NO: 2626 items (46.2%) | ₦628,172,564,174
#    YES: 2451 items (43.1%) | ₦1,331,965,056,587
#    PARTIAL: 609 items (10.7%) | ₦250,736,845,388
#
# 🚨 Items flagged as NOT aligned: 2626
#    Flagged amount: ₦628,172,564,174
#
# ...
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ...
#
# 🚨 ERGP12234386: ROADS REHABILITATION IN SELECTED LOCATIONS IN NORTH WEST, NI...
#    Agency: FEDERAL ROAD MAINTENANCE AGENCY
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
#    Reason: FERMA's mandate is limited to routine and periodic maintenance of existing federal roads, while road rehabilitation involves major reconstruction work that falls under the Federal Ministry of Works' capital projects mandate.
#
# 🚨 ERGP1246025: CONSTRUCTION OF POLICE TRAINING INSTITUTE (SHORT SERVICE) , ...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
# ...

# %%
result_df.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
# Calculate total
total = result_df['amount'].sum()
total_formatted = f"Total: ₦{total:,.2f}"

# A: Sum amount where alignment is NO
flagged = result_df[result_df["alignment"] == "NO"]
flagged_amount = flagged['amount'].sum()
flagged_amount_naira = f"₦{flagged_amount:.2f}"
# B: Sum amount for full filtered dataframe
total_mda_project_value = f"₦{total:.2f}"
# C: A/B
flagged_percentage = flagged_amount/total
# Format the output as a percentage with 2 decimal places
format_flagged_as_percent = f"{flagged_percentage:.2%}"

# %%
total_mda_project_value
# Out:
# '₦2210874466149.00'

# %%
format_flagged_as_percent
# Out:
# '28.41%'

# %%
flagged_amount_naira
# Out:
# '₦628172564174.00'

# %%
mandate_deviation_output_path_1_50 = "data/outputs/mandate_deviation/llm_alignment_results_1_to_50.csv"
result_df_1_50 = pd.read_csv(mandate_deviation_output_path_1_50)

# %%
print(len(result_df_1_50))
# Out:
# 2355

# %%
# Calculate total
total = result_df['amount'].sum()
total_formatted = f"Total: ₦{total:,.2f}"

# A: Sum amount where alignment is NO
flagged = result_df[result_df["alignment"] == "NO"]
flagged_amount = flagged['amount'].sum()
flagged_amount_naira = f"₦{flagged_amount:.2f}"
# B: Sum amount for full filtered dataframe
total_mda_project_value = f"₦{total:.2f}"
# C: A/B
flagged_percentage = flagged_amount/total
# Format the output as a percentage with 2 decimal places
format_flagged_as_percent = f"{flagged_percentage:.2%}"

# %%
flagged_amount_naira
# Out:
# '₦144628302649.00'

# %%
# 3. View results
print_summary_llm(result_df_1_50)
print_flagged_items_llm(result_df_1_50)


pass
# Out:
# ...
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ...
#
# Total Budget Items: 2355
# Total Budget Amount: ₦780,536,740,991
#
# Alignment Distribution:
#    YES: 1261 items (53.5%) | ₦208,782,504,556
#    NO: 812 items (34.5%) | ₦144,628,302,649
#    PARTIAL: 282 items (12.0%) | ₦427,125,933,786
#
# 🚨 Items flagged as NOT aligned: 812
#    Flagged amount: ₦144,628,302,649
#
# ...
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ...
#
# 🚨 ERGP16234836: "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT HEADQUARTER OFF...
#    Agency: BUREAU OF PUBLIC ENTERPRISES (BPE)
#    Amount: ₦14,000,000,000
#    Confidence: HIGH
#    Reason: The budget item refers to acquiring headquarters for the Bureau of Public Procurement, which is a completely different agency from the Bureau of Public Enterprises and falls outside BPE's mandate of privatisation and commercialisation.
#
# 🚨 ERGP22242227: COMPLETION AND EQUIPPING OF GENERAL HOSPITALS (MULTIPLE LOTS...
#    Agency: AMINU KANO UNIVERSITY TEACHING HOSPITAL
#    Amount: ₦4,200,000,000
# ...

# %%
print(len(result_df_1_50))
# Out:
# 2355

# %%
mandate_deviation_output_path_51_200 = "data/outputs/mandate_deviation/llm_alignment_results_51_to_200.csv"
result_df_51_200 = pd.read_csv(mandate_deviation_output_path_51_200)

# %%
print(len(result_df_51_200))
# Out:
# 5686

# %%
# Merge vertically (stack rows)
merged_mandate_deviation_for_mdas_1_200_df = pd.concat([result_df_1_50, result_df_51_200], ignore_index=True)

# %%
print(len(merged_mandate_deviation_for_mdas_1_200_df))
# Out:
# 8041

# %%
cols = ['code', 'ergp_line_item', 'mda_code', 'amount']

# %%
duplicates = merged_mandate_deviation_for_mdas_1_200_df[merged_mandate_deviation_for_mdas_1_200_df.duplicated(subset=cols)]

# %%
duplicates.head()
# Out:
#              code                                     ergp_line_item  \
# 800  ERGP30242140  CONSTRUCTION OF AL-QUAREEB COMMUNITY MOSQUE AN...
# 801  ERGP30242141  RENOVATION OF SCHOOLS IN IBARAPA EAST/IDO FEDE...
# 802  ERGP30242143  CONSTRUCTION OF WELL EQUIPPED I.C.T CENTER IN ...
# 803  ERGP30242145  PROVISION OF MOTORISED BOREHOLE ACROSS OGO-OLU...
# 804  ERGP30242146  PROVISION OF ALL IN ONE SOLAR POWERED STREETLI...
#
#       mda_code                            agency  mother_ministry  \
# 800  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 801  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 802  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 803  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 804  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
#
#           amount alignment confidence  \
# 800  280000000.0        NO       HIGH
# 801  140000000.0        NO       HIGH
# ...

# %%
print(len(duplicates))
# Out:
# 235

# %%
merged_mandate_deviation_for_mdas_1_200_df_no_duplicates = merged_mandate_deviation_for_mdas_1_200_df.drop_duplicates(subset=cols)

# %%
merged_mandate_deviation_for_mdas_1_200_df_no_duplicates.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# ...

# %%
df = merged_mandate_deviation_for_mdas_1_200_df_no_duplicates.reset_index(drop=True)

# %%
mandate_deviation_output_path_1_200 = "data/outputs/mandate_deviation/llm_alignment_results_1_to_200_combined.csv"
df.to_csv(mandate_deviation_output_path_1_200, index=False)

# %%
df.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# ...

# %%
street_light_list = ['STREET LIGHT', 'streetlight', 'street lights', 'streetlights']
# Filter the DataFrame
street_lights_df = df[df['ergp_line_item'].isin(street_light_list)]

# street_lights_df = df[df['ergp_line_item'].str.lower().isin(street_light_list)]



# List of keywords to check
# keywords = ['test', 'test2']

# Create a regular expression pattern by joining the keywords with '|'
pattern = '|'.join(street_light_list)

# Filter the DataFrame for rows where any keyword occurs in the column
street_lights_df = df[df['ergp_line_item'].str.contains(pattern, case=False, na=False)]

# print(street_lights_df)
# Out:
#               code                                     ergp_line_item  \
# 40    ERGP10225206  SOLAR STREET LIGHT SYSTEM FOR ACADEMIC AREAS A...
# 128   ERGP10236498  THREE-IN-ONE SOLAR STREET LIGHT IN OGBARU FEDE...
# 129   ERGP10236499  PROVISION OF SOLAR STREET LIGHT IN ALIERO/GWAN...
# 130   ERGP10236500  PROVISION OF SOLAR STREET LIGHT IN GORONYO/GAD...
# 132   ERGP10236527  PROVISION AND INSTALATION OF STREETLIGHTS IN K...
# ...            ...                                                ...
# 7310  ERGP25242158  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7312  ERGP25242166  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7409  ERGP25226606                 PROVISION OF SOLAR STREET LIGHTS\n
# 7628  ERGP25240706  SUPPLY AND INSTALLATION OF SOLAR POWERED STREE...
# 7711  ERGP10224538  REHABILITATION/INSTALLATION OF STREET LIGHTS A...
#
#        mda_code                                             agency  \
# ...

# %%
street_lights_df
# Out:
#               code                                     ergp_line_item  \
# 40    ERGP10225206  SOLAR STREET LIGHT SYSTEM FOR ACADEMIC AREAS A...
# 128   ERGP10236498  THREE-IN-ONE SOLAR STREET LIGHT IN OGBARU FEDE...
# 129   ERGP10236499  PROVISION OF SOLAR STREET LIGHT IN ALIERO/GWAN...
# 130   ERGP10236500  PROVISION OF SOLAR STREET LIGHT IN GORONYO/GAD...
# 132   ERGP10236527  PROVISION AND INSTALATION OF STREETLIGHTS IN K...
# ...            ...                                                ...
# 7310  ERGP25242158  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7312  ERGP25242166  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7409  ERGP25226606                 PROVISION OF SOLAR STREET LIGHTS\n
# 7628  ERGP25240706  SUPPLY AND INSTALLATION OF SOLAR POWERED STREE...
# 7711  ERGP10224538  REHABILITATION/INSTALLATION OF STREET LIGHTS A...
#
#        mda_code                                             agency  \
# ...

# %%
street_light_total = street_lights_df['amount'].sum()
print(street_light_total/1000000000)
# Out:
# 118.242932783

# %%
df.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# ...

# %%
print(len(street_lights_df['mda_code'].unique()))
# Out:
# 44

# %%
mdas_1_891_no_duplicates

# %%
street_light_list = ['STREET LIGHT', 'streetlight', 'street lights', 'streetlights']
# Filter the DataFrame
# street_lights_df2 = mdas_1_891_no_duplicates[mdas_1_891_no_duplicates['ergp_line_item'].isin(street_light_list)]

# street_lights_df = df[df['ergp_line_item'].str.lower().isin(street_light_list)]



# List of keywords to check
# keywords = ['test', 'test2']

# Create a regular expression pattern by joining the keywords with '|'
pattern = '|'.join(street_light_list)

# Filter the DataFrame for rows where any keyword occurs in the column
street_lights_df2 = mdas_1_891_no_duplicates[mdas_1_891_no_duplicates['ergp_line_item'].str.contains(pattern, case=False, na=False)]

# print(street_lights_df)

# %%
street_lights_df2['amount'].sum()/1000000000
# Out:
# 278.491847158

# %%
print(len(street_lights_df2['mda_code'].unique()))
# Out:
# 133

# %%
print(len(budget_df['code'].unique()))
# Out:
# 27535

# %% [markdown]
# ## 04 April 2026 - Remaining 7,148 projects

# %%
# Mandate data ingestion
input_path_csv = "data/inputs/master_combined_mandate_1_to_891.csv"

mandate_df_1_891 = pd.read_csv(input_path_csv)

# %%
print(len(mandate_df_1_891))
# Out:
# 876

# %%
mandate_df_1_891.head()
# Out:
#     mda_code                                           mda_name  \
# 0  521025001          41. COMMUNITY HEALTH TUTOR PROGRAMME, UCH
# 1  517015001  42. COMPUTER PROFESSIONALS (REGISTRATION COUNC...
# 2  119009118  43. CONSULATE GENERAL OF NIGERIA, FRANKFURT, G...
# 3  234005001  44. COUNCIL FOR THE REGULATION OF ENGINEERING ...
# 4  229006001  45. COUNCIL FOR THE REGULATION OF FREIGHT FORW...
#
#                                  mandate_description
# 0  The Community Health Tutor Programme at the Un...
# 1  The Computer Professionals (Registration Counc...
# 2  The Consulate General of the Federal Republic ...
# 3  The Council for the Regulation of Engineering ...
# 4  The Council for the Regulation of Freight Forw...

# %%
# Mandate data ingestion
budget_input_path_csv = "data/outputs/ergp_budget_2026_proposed_remaining_7148_projects.csv"

budget_df_remaining_7148 = pd.read_csv(budget_input_path_csv)

# %%
print(len(budget_df_remaining_7148))
# Out:
# 7148

# %%
budget_df_remaining_7148.head()
# Out:
#            code                                     ergp_line_item   status  \
# 0  ERGP15172225  COMPUTERISATION OF THE INTERNAL AUDIT DEPARTME...  ONGOING
# 1  ERGP15172263     ESTABLISHMENT OF CONDUCT OF CORRUPTION INDEX\n  ONGOING
# 2  ERGP16172270  CAPACITY BUILDING FOR INFORMATION, ADMIN AND A...  ONGOING
# 3  ERGP16204356  DIGITIZATION OF VOTE BOOKS, CASH BOOKS, FIXED ...  ONGOING
# 4  ERGP16204392        ATTENDANCE OF NATIONAL COUNCIL ON IMATION\n  ONGOING
#
#        amount     mda_code                                             agency  \
# 0  15559347.0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 1   7125580.0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 2  15680000.0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 3  13860000.0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 4   3871658.0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
#
#    mother_ministry
# 0              NaN
# ...

# %%
mda_list = budget_df_remaining_7148['mda_code'].unique().tolist()
print(len(mda_list))
# Out:
# 131

# %%
filtered_mandate_df = mandate_df_1_891[mandate_df_1_891['mda_code'].isin(mda_list)]

# %%
filtered_mandate_df = filtered_mandate_df.reset_index(drop=True)

# %%
filtered_mandate_df.tail()
# Out:
#       mda_code                                           mda_name  \
# 114  254001001  176. FEDERAL MINISTRY OF MARINE AND BLUE ECONO...
# 115  451001001         177. FEDERAL MINISTRY OF NIGER DELTA HQTRS
# 116  155001001            178. FEDERAL MINISTRY OF POLICE AFFAIRS
# 117  231001001              179. FEDERAL MINISTRY OF POWER -HQTRS
# 118  228001001  180. FEDERAL MINISTRY OF SCIENCE, TECHNOLOGY A...
#
#                                    mandate_description
# 114  The Federal Ministry of Marine and Blue Econom...
# 115  The Federal Ministry of Niger Delta Affairs wa...
# 116  The Federal Ministry of Police Affairs was est...
# 117  The Federal Ministry of Power is responsible f...
# 118  The Federal Ministry of Science, Technology an...

# %%
print(len(filtered_mandate_df))
# Out:
# 119

# %%
# =============================================================================
#  USAGE - remaining 7,148 projects
# =============================================================================


# Example usage (replace with your actual data)

# 1. Set your API key
api_key = ANTHROPIC_API_KEY

# 2. Run analysis
result_df = analyze_budget_mandate_alignment_llm(
    budget_df=budget_df_remaining_7148,
    mandate_df=filtered_mandate_df,
    api_key=api_key,
    progress_interval=10
)
# Out:
# Analyzing 7148 budget items with Claude...
# Estimated time: 178.7 - 297.8 minutes
# ...
#    Processed 10/7148 (0.1%) | Elapsed: 0.4min | Remaining: 289.4min
#    Processed 20/7148 (0.3%) | Elapsed: 0.8min | Remaining: 277.8min
#    Processed 30/7148 (0.4%) | Elapsed: 1.2min | Remaining: 286.7min
#    Processed 40/7148 (0.6%) | Elapsed: 1.6min | Remaining: 280.9min
#    Processed 50/7148 (0.7%) | Elapsed: 2.0min | Remaining: 279.1min
#    Processed 60/7148 (0.8%) | Elapsed: 2.3min | Remaining: 274.9min
#    Processed 70/7148 (1.0%) | Elapsed: 2.7min | Remaining: 273.9min
#    Processed 80/7148 (1.1%) | Elapsed: 3.1min | Remaining: 274.3min
#    Processed 90/7148 (1.3%) | Elapsed: 3.5min | Remaining: 274.6min
#    Processed 100/7148 (1.4%) | Elapsed: 3.9min | Remaining: 272.7min
#    Processed 110/7148 (1.5%) | Elapsed: 4.3min | Remaining: 272.9min
#    Processed 120/7148 (1.7%) | Elapsed: 4.7min | Remaining: 272.6min
#    Processed 130/7148 (1.8%) | Elapsed: 5.1min | Remaining: 273.1min
# ...

# %%
# 3. View results
print_summary_llm(result_df)
print_flagged_items_llm(result_df)

# 4. Export
result_df.to_csv("llm_alignment_results_remaining_7148.csv", index=False)

pass
# Out:
# ...
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ...
#
# Total Budget Items: 7148
# Total Budget Amount: ₦5,284,169,907,874
#
# Alignment Distribution:
#    YES: 4889 items (68.4%) | ₦4,214,756,672,651
#    PARTIAL: 1160 items (16.2%) | ₦712,436,930,758
#    NO: 995 items (13.9%) | ₦339,152,770,797
#    UNKNOWN: 102 items (1.4%) | ₦17,365,733,668
#    ERROR: 2 items (0.0%) | ₦457,800,000
#
# 🚨 Items flagged as NOT aligned: 995
#    Flagged amount: ₦339,152,770,797
#
# ...
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ...
#
# 🚨 ERGP1247779: CONTINGENCY FUND...
#    Agency: FEDERAL MINISTRY OF WORKS
#    Amount: ₦100,000,000,000
#    Confidence: HIGH
#    Reason: A contingency fund is a general financial reserve that does not align with the Federal Ministry of Works' specific mandate to construct, rehabilitate and maintain federal roads and bridges infrastructure.
#
# 🚨 ERGP12231824: CONTINGENCY FUND
# ...
#    Agency: FEDERAL MINISTRY OF WORKS
#    Amount: ₦10,514,000,000
#    Confidence: HIGH
# ...

# %% [markdown]
# ### Export content

# %%
mandate_deviation_to_20_000_projects_path = "data/outputs/mandate_deviation/combined_llm_alignment_results_1_891.csv"
mandate_deviation_to_20_000_projects = pd.read_csv(mandate_deviation_to_20_000_projects_path)

# %%
mandate_deviation_to_20_000_projects.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# ...

# %%
llm_alignment_results_remaining_7148_path = "data/outputs/mandate_deviation/llm_alignment_results_remaining_7148.csv"
llm_alignment_results_remaining_7148_projects = pd.read_csv(llm_alignment_results_remaining_7148_path)

# %%
llm_alignment_results_remaining_7148_projects.head()
# Out:
#            code                                     ergp_line_item  \
# 0  ERGP15172225  COMPUTERISATION OF THE INTERNAL AUDIT DEPARTME...
# 1  ERGP15172263     ESTABLISHMENT OF CONDUCT OF CORRUPTION INDEX\n
# 2  ERGP16172270  CAPACITY BUILDING FOR INFORMATION, ADMIN AND A...
# 3  ERGP16204356  DIGITIZATION OF VOTE BOOKS, CASH BOOKS, FIXED ...
# 4  ERGP16204392        ATTENDANCE OF NATIONAL COUNCIL ON IMATION\n
#
#       mda_code                                             agency  \
# 0  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 1  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 2  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 3  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
# 4  123001001.0  FEDERAL MINISTRY OF INFORMATION AND NATIONAL O...
#
#    mother_ministry      amount alignment confidence  \
# 0              NaN  15559347.0   PARTIAL     MEDIUM
# 1              NaN   7125580.0   PARTIAL     MEDIUM
# ...

# %%
# Basic concat
# combined = pd.concat([mandate_deviation_to_20_000_projects, llm_alignment_results_remaining_7148_projects])

# Reset index after stacking
combined_all_budget = pd.concat([mandate_deviation_to_20_000_projects, llm_alignment_results_remaining_7148_projects], ignore_index=True)

# %%
combined_all_budget.head()
# Out:
#            code                                     ergp_line_item  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...
#
#       mda_code                              agency  mother_ministry  \
# 0  111007001.0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN
# 1  111007001.0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN
# 2  111007001.0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN
# 3  111007001.0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN
# 4  111007001.0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN
#
#          amount alignment confidence  \
# 0  9.817500e+07       YES       HIGH
# 1  1.490738e+07       YES       HIGH
# ...

# %%
print(len(combined_all_budget))
# Out:
# 27539

# %%
llm_alignment_results_combined_all_budget = "data/outputs/mandate_deviation/llm_alignment_results_complete_27_540_projects.csv"
combined_all_budget.to_csv(llm_alignment_results_combined_all_budget, index=False)
