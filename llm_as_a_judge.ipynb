# %%
import pandas as pd

# %%
# Mandate data ingestion
input_path_csv = "data/inputs/combine_mandate_51_to_380.csv"

mandate_df_51_380 = pd.read_csv(input_path_csv)

# %%
mandate_df_51_380.head()
# Out:
#     mda_code                                           mda_name  \
# 0  517026002  # NIGERIAN FEDERAL AGENCY MANDATES: AGENCIES 3...
# 1  517026004                              302. FGC BIRNIN YAURI
# 2  517026003                                 303. FGC BUNI-YADI
# 3  517026005                                     304. FGC DAURA
# 4  517026006                                     305. FGC GANYE
#
#                                  mandate_description
# 0  **MDA Code:** 517026002\n\nFederal Government ...
# 1  Federal Government College Birnin Yauri, Kebbi...
# 2  Federal Government College Buni-Yadi, Yobe Sta...
# 3  Federal Government College Daura, Katsina Stat...
# 4  Federal Government College Ganye, Adamawa Stat...

# %%
mandate_df_51_380.dtypes
# Out:
# mda_code                int64
# mda_name               object
# mandate_description    object
# dtype: object

# %%
ergp_budget_with_mda_path = "data/outputs/ergp_budget_with_mda.csv"
budget_df = pd.read_csv(ergp_budget_with_mda_path)

# %%
print(len(budget_df))
# Out:
# 28805

# %%
budget_df.head()
# Out:
#            code                                     ergp_line_item   status  \
# 0  ERGP30102445                     UPGRADE OF STATE HOUSE LIBRARY  ONGOING
# 1  ERGP30114992  DIGITAL MEDICAL REFERENCES FOR THE STATE HOUSE...  ONGOING
# 2   ERGP6101477  REHABILITATION OF ANIMAL ENCLOSURE/PROCUREMENT...  ONGOING
# 3   ERGP6114996  CONVERSION/UPGRADE OF VILLA RANCH AND CONSTRUC...  ONGOING
# 4   ERGP6114997  PURCHASE OF PLANT NURSERY EQUIPMENT FOR PRODUC...  ONGOING
#
#        amount   mda_code               agency  mother_ministry
# 0   9,028,123  111001001  STATE HOUSE - HQTRS              NaN
# 1   3,219,762  111001001  STATE HOUSE - HQTRS              NaN
# 2  21,850,216  111001001  STATE HOUSE - HQTRS              NaN
# 3  38,466,135  111001001  STATE HOUSE - HQTRS              NaN
# 4  26,912,671  111001001  STATE HOUSE - HQTRS              NaN

# %%
budget_df.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount              object
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
# Remove commas and convert to float
budget_df['amount'] = budget_df['amount'].str.replace(',', '').astype('float64')

# %%
budget_df.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount             float64
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
# MDAs for 1 - 50
test_mdas = [
    521025001,
    517015001,
    119009118,
    234005001,
    229006001,
    326004001,
    257005001,
    535007001,
    252040001,
    517021051,
    515050001,
    517021023,
    252038001,
    228009001,
    161022001,
    238005001,
    111007001,
    111010001,
    161025001,
    256009001,
    238003001,
    535005001,
    252039001,
    555003001,
    124005001,
    215014001,
    344001001,
    158001001,
    116008001,
    521010001,
    521026016,
    517021015,
    517021055,
    125003001,
    116004003,
    123011001,
    215003001,
    215054001,
    521026003,
    517021004,
    116005003,
    116005002,
    233011001,
    517018008,
    517021032,
    517021056,
    521026013,
    252037001,
    517021027,
    140001001
]

mda_list_51_200 = [
    517026002,
    517026004,
    517026003,
    517026005,
    517026006,
    517026007,
    517026008,
    517026009,
    517026010,
    517026011,
    517026012,
    517026013,
    517026014,
    517026015,
    517026016,
    517026017,
    517026018,
    517026019,
    517026020,
    517026021,
    521027037,
    521027026,
    521027056,
    521027038,
    521027062,
    521027027,
    521027049,
    521027035,
    521027065,
    521027033,
    521027031,
    521027021,
    521027055,
    521027036,
    521027024,
    521027018,
    521027034,
    521027017,
    521027067,
    215001001,
    517018029,
    517018034,
    517018030,
    517018031,
    517018033,
    222011001,
    521027012,
    521027006,
    521027004,
    521027005,
    521027007,
    123004001,
    234004001,
    161007001,
    161007002,
    161007003,
    161007004,
    161007005,
    521027042,
    521035001,
    517018015,
    517018026,
    517018011,
    517018021,
    517018016,
    517018004,
    517018018,
    517018009,
    517018027,
    517018005,
    517018006,
    517018007,
    517018013,
    517018010,
    517018014,
    517018023,
    517018025,
    517018035,
    517018032,
    517018036,
    517026052,
    517026053,
    517026054,
    517026055,
    517026056,
    517026076,
    517026057,
    517026058,
    517026059,
    517026060,
    517026061,
    517026062,
    517026063,
    517026064,
    517026065,
    517026066,
    517026067,
    517026068,
    517026069,
    517026070,
    517026071,
    517026072,
    517026073,
    517026074,
    517026075,
    517026077,
    517026078,
    517026079,
    250001001,
    119009001,
    521026024,
    517021049,
    517021046,
    517021053,
    517021054,
    517021059,
    517023001,
    521026033,
    517021062,
    517021017,
    517021047,
    517021048,
    517021018,
    229032001,
    517021030,
    517021029,
    521026030,
    521026027,
    517021037,
    517021050,
    517021034,
    517021039,
    517021035,
    517021033,
    517021036,
    517021063,
    517021065,
    215012005,
    215012004,
    215012001,
    215012002,
    215012006,
    517021058,
    517021061,
    517021067,
    517021060,
    517021068,
    517021040,
    517021066,
    521026031,
    254009001,
    215034001,
    215032001,
    215033001,
    215002001,
    265006001,
    535010001,
    222032001,
    124007001,
    125002001,
    228046001,
    521027003,
    521027019,
    521027059,
    521027066,
    521027061,
    521027058,
    521027057,
    521027025,
    521027032,
    521026022,
    220002001,
    116002001,
    116010001,
    116012001,
    116012002,
    116011001,
    116015017,
    116002002,
    116018001,
    116018002,
    521007001,
    521039001,
    157002001,
    119007001,
    517022001,
    111009001,
    228073001,
    521017001,
    535017001,
    220024001,
    222012001,
    517026001,
    437001001,
    149001001,
    147001001,
    215029001,
    215030001,
    215031001,


]

# %%
budget_df_mda_51_200 = budget_df[budget_df['mda_code'].isin(mda_list_51_200)]

# %%
print(len(budget_df_mda_51_200))
# Out:
# 5686

# %%
budget_df_mda_51_200.dtypes
# Out:
# code                object
# ergp_line_item      object
# status              object
# amount             float64
# mda_code             int64
# agency              object
# mother_ministry    float64
# dtype: object

# %%
# code	ergp_line_item	mda	amount	similarity_score	mandate_deviation_score

# %% [markdown]
# ### LLM-AS-JUDGE:

# %%
# =============================================================================
# LLM-AS-JUDGE: CLAUDE API IMPLEMENTATION
# =============================================================================

import anthropic
import pandas as pd
import time
from typing import Optional


# =============================================================================
# CONFIGURATION
# =============================================================================

ANTHROPIC_API_KEY = "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"  # Replace with your key
MODEL_NAME = "claude-sonnet-4-20250514"  # Good balance of speed/cost/quality
MAX_RETRIES = 3
RETRY_DELAY = 2  # seconds

# %%
# =============================================================================
# CORE FUNCTIONS
# =============================================================================

def create_client(api_key: str = ANTHROPIC_API_KEY) -> anthropic.Anthropic:
    """Create Anthropic client."""
    return anthropic.Anthropic(api_key=api_key)


def judge_alignment(
    client: anthropic.Anthropic,
    line_item: str,
    agency: str,
    mandate: str
) -> dict:
    """
    Use Claude to judge if budget item aligns with agency mandate.
    
    Returns:
        dict with keys: alignment, confidence, reason
    """
    prompt = f"""You are an auditor checking if Nigerian government budget items align with agency mandates.

    AGENCY: {agency}

    AGENCY MANDATE: {mandate}

    BUDGET LINE ITEM: {line_item}

    Does this budget item fall within the agency's mandate?

    Respond in EXACTLY this format (no other text):
    ALIGNMENT: YES or PARTIAL or NO
    CONFIDENCE: HIGH or MEDIUM or LOW
    REASON: (one sentence explanation)"""

    for attempt in range(MAX_RETRIES):
        try:
            response = client.messages.create(
                model=MODEL_NAME,
                max_tokens=150,
                messages=[
                    {"role": "user", "content": prompt}
                ]
            )
            
            result_text = response.content[0].text
            return parse_llm_response(result_text)
            
        except Exception as e:
            if attempt < MAX_RETRIES - 1:
                print(f"   Retry {attempt + 1}/{MAX_RETRIES} after error: {e}")
                time.sleep(RETRY_DELAY)
            else:
                print(f"   Failed after {MAX_RETRIES} attempts: {e}")
                return {
                    "alignment": "ERROR",
                    "confidence": "UNKNOWN",
                    "reason": str(e)
                }


def parse_llm_response(response: str) -> dict:
    """Parse the structured LLM response."""
    result = {
        "alignment": "UNKNOWN",
        "confidence": "UNKNOWN",
        "reason": ""
    }
    
    lines = response.strip().split("\n")
    
    for line in lines:
        line = line.strip()
        if line.upper().startswith("ALIGNMENT:"):
            value = line.split(":", 1)[1].strip().upper()
            if value in ["YES", "PARTIAL", "NO"]:
                result["alignment"] = value
        elif line.upper().startswith("CONFIDENCE:"):
            value = line.split(":", 1)[1].strip().upper()
            if value in ["HIGH", "MEDIUM", "LOW"]:
                result["confidence"] = value
        elif line.upper().startswith("REASON:"):
            result["reason"] = line.split(":", 1)[1].strip()
    
    return result


def compute_deviation_score(alignment: str, confidence: str) -> float:
    """
    Convert alignment + confidence to a deviation score (0-100).
    
    Higher score = more likely outside mandate = higher audit priority.
    """
    alignment_scores = {
        "YES": 0,
        "PARTIAL": 50,
        "NO": 100,
        "UNKNOWN": 50,
        "ERROR": 50
    }
    
    confidence_adjustments = {
        "HIGH": 0,
        "MEDIUM": 5,
        "LOW": 10,
        "UNKNOWN": 10
    }
    
    base_score = alignment_scores.get(alignment, 50)
    adjustment = confidence_adjustments.get(confidence, 10)
    
    # For YES: add adjustment (less confident YES = slightly higher deviation)
    # For NO: subtract adjustment (less confident NO = slightly lower deviation)
    if alignment == "YES":
        return min(base_score + adjustment, 100)
    elif alignment == "NO":
        return max(base_score - adjustment, 0)
    else:
        return base_score


# =============================================================================
# MAIN ANALYSIS FUNCTION
# =============================================================================

def analyze_budget_mandate_alignment_llm(
    budget_df: pd.DataFrame,
    mandate_df: pd.DataFrame,
    api_key: str = ANTHROPIC_API_KEY,
    progress_interval: int = 10
) -> pd.DataFrame:
    """
    Analyze alignment between budget items and agency mandates using Claude.
    
    Args:
        budget_df: DataFrame with columns [code, ergp_line_item, mda_code, agency, mother_ministry, amount]
        mandate_df: DataFrame with columns [mda_code, mda_name, mandate_description]
        api_key: Anthropic API key
        progress_interval: Print progress every N items
        
    Returns:
        DataFrame with alignment results
    """
    # Create client
    client = create_client(api_key)
    
    # Create mandate lookup by mda_code
    mandate_lookup = dict(zip(mandate_df["mda_code"], mandate_df["mandate_description"]))
    
    results = []
    total_items = len(budget_df)
    
    print(f"Analyzing {total_items} budget items with Claude...")
    print(f"Estimated time: {total_items * 1.5 / 60:.1f} - {total_items * 2.5 / 60:.1f} minutes")
    print("=" * 60)
    
    start_time = time.time()
    
    for i, (_, row) in enumerate(budget_df.iterrows()):
        mda_code = row["mda_code"]
        line_item = row["ergp_line_item"]
        agency = row["agency"]
        mandate = mandate_lookup.get(mda_code, "")
        
        if mandate:
            judgement = judge_alignment(client, line_item, agency, mandate)
        else:
            judgement = {
                "alignment": "UNKNOWN",
                "confidence": "UNKNOWN",
                "reason": "No mandate found for this agency"
            }
        
        deviation = compute_deviation_score(
            judgement["alignment"], 
            judgement["confidence"]
        )
        
        results.append({
            "code": row["code"],
            "ergp_line_item": row["ergp_line_item"],
            "mda_code": row["mda_code"],
            "agency": row["agency"],
            "mother_ministry": row["mother_ministry"],
            "amount": row["amount"],
            "alignment": judgement["alignment"],
            "confidence": judgement["confidence"],
            "reason": judgement["reason"],
            "mandate_deviation_score": deviation
        })
        
        # Progress update
        if (i + 1) % progress_interval == 0 or (i + 1) == total_items:
            elapsed = time.time() - start_time
            rate = (i + 1) / elapsed
            remaining = (total_items - i - 1) / rate if rate > 0 else 0
            print(f"   Processed {i + 1}/{total_items} ({(i+1)/total_items*100:.1f}%) | "
                  f"Elapsed: {elapsed/60:.1f}min | Remaining: {remaining/60:.1f}min")
    
    print("=" * 60)
    print("Analysis complete.")
    
    return pd.DataFrame(results)

# %%
# =============================================================================
# OUTPUT & REPORTING
# =============================================================================

def print_summary_llm(result_df: pd.DataFrame) -> None:
    """Print summary statistics for LLM analysis."""
    print("\n" + "=" * 80)
    print("SUMMARY: LLM-AS-JUDGE ANALYSIS")
    print("=" * 80)
    
    total_items = len(result_df)
    total_amount = result_df["amount"].sum()
    
    # Alignment distribution
    alignment_counts = result_df["alignment"].value_counts()
    
    print(f"\nTotal Budget Items: {total_items}")
    print(f"Total Budget Amount: ₦{total_amount:,.0f}")
    
    print(f"\nAlignment Distribution:")
    for alignment, count in alignment_counts.items():
        pct = count / total_items * 100
        amount = result_df[result_df["alignment"] == alignment]["amount"].sum()
        print(f"   {alignment}: {count} items ({pct:.1f}%) | ₦{amount:,.0f}")
    
    # Flagged items (NO alignment)
    flagged = result_df[result_df["alignment"] == "NO"]
    print(f"\n🚨 Items flagged as NOT aligned: {len(flagged)}")
    print(f"   Flagged amount: ₦{flagged['amount'].sum():,.0f}")


def print_flagged_items_llm(result_df: pd.DataFrame, top_n: int = 20) -> None:
    """Print items flagged as not aligned."""
    flagged = result_df[result_df["alignment"] == "NO"].sort_values(
        "amount", ascending=False
    ).head(top_n)
    
    if len(flagged) == 0:
        print("\n✅ No items flagged as misaligned!")
        return
    
    print("\n" + "=" * 100)
    print(f"TOP {top_n} FLAGGED ITEMS (NOT ALIGNED)")
    print("=" * 100)
    
    for _, row in flagged.iterrows():
        print(f"\n🚨 {row['code']}: {row['ergp_line_item'][:60]}...")
        print(f"   Agency: {row['agency']}")
        print(f"   Amount: ₦{row['amount']:,.0f}")
        print(f"   Confidence: {row['confidence']}")
        print(f"   Reason: {row['reason']}")

# %%
# =============================================================================
#  USAGE 51 - 200
# =============================================================================
# budget_df_1_to_50
# mandate_df_1_50

# Example usage (replace with your actual data)

# 1. Set your API key
api_key = ANTHROPIC_API_KEY

# 2. Run analysis
result_df = analyze_budget_mandate_alignment_llm(
    budget_df=budget_df_mda_51_200,
    mandate_df=mandate_df_51_380,
    api_key=api_key,
    progress_interval=10
)
# Out:
# Analyzing 5686 budget items with Claude...
# Estimated time: 142.2 - 236.9 minutes
# ============================================================
#    Processed 10/5686 (0.2%) | Elapsed: 0.5min | Remaining: 292.9min
#    Processed 20/5686 (0.4%) | Elapsed: 1.0min | Remaining: 285.6min
#    Processed 30/5686 (0.5%) | Elapsed: 1.5min | Remaining: 285.7min
#    Processed 40/5686 (0.7%) | Elapsed: 2.0min | Remaining: 285.4min
#    Processed 50/5686 (0.9%) | Elapsed: 2.5min | Remaining: 282.3min
#    Processed 60/5686 (1.1%) | Elapsed: 3.0min | Remaining: 285.1min
#    Processed 70/5686 (1.2%) | Elapsed: 3.6min | Remaining: 286.2min
#    Processed 80/5686 (1.4%) | Elapsed: 4.1min | Remaining: 285.5min
#    Processed 90/5686 (1.6%) | Elapsed: 4.6min | Remaining: 287.9min
#    Processed 100/5686 (1.8%) | Elapsed: 5.2min | Remaining: 289.7min
#    Processed 110/5686 (1.9%) | Elapsed: 5.7min | Remaining: 288.8min
#    Processed 120/5686 (2.1%) | Elapsed: 6.2min | Remaining: 289.5min
#    Processed 130/5686 (2.3%) | Elapsed: 6.8min | Remaining: 289.1min
#    Processed 140/5686 (2.5%) | Elapsed: 7.3min | Remaining: 289.4min
#    Processed 150/5686 (2.6%) | Elapsed: 7.8min | Remaining: 288.4min
#    Processed 160/5686 (2.8%) | Elapsed: 8.3min | Remaining: 286.1min
#    Processed 5580/5686 (98.1%) | Elapsed: 307.3min | Remaining: 5.8min
#    Processed 5590/5686 (98.3%) | Elapsed: 307.8min | Remaining: 5.3min
#    Processed 5600/5686 (98.5%) | Elapsed: 308.3min | Remaining: 4.7min
#    Processed 5610/5686 (98.7%) | Elapsed: 308.8min | Remaining: 4.2min
#    Processed 5620/5686 (98.8%) | Elapsed: 309.3min | Remaining: 3.6min
#    Processed 5630/5686 (99.0%) | Elapsed: 309.8min | Remaining: 3.1min
#    Processed 5640/5686 (99.2%) | Elapsed: 310.4min | Remaining: 2.5min
#    Processed 5650/5686 (99.4%) | Elapsed: 310.9min | Remaining: 2.0min
#    Processed 5660/5686 (99.5%) | Elapsed: 311.4min | Remaining: 1.4min
#    Processed 5670/5686 (99.7%) | Elapsed: 311.9min | Remaining: 0.9min
#    Processed 5680/5686 (99.9%) | Elapsed: 312.5min | Remaining: 0.3min
#    Processed 5686/5686 (100.0%) | Elapsed: 312.7min | Remaining: 0.0min
# ============================================================
# Analysis complete.

# %%
result_df.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
print(len(result_df))
# Out:
# 5686

# %%
result_df.dtypes
# Out:
# code                        object
# ergp_line_item              object
# mda_code                     int64
# agency                      object
# mother_ministry            float64
# amount                     float64
# alignment                   object
# confidence                  object
# reason                      object
# mandate_deviation_score      int64
# dtype: object

# %%
# 3. View results
print_summary_llm(result_df)
print_flagged_items_llm(result_df)

# 4. Export
result_df.to_csv("llm_alignment_results_51_to_200.csv", index=False)

pass
# Out:
# ================================================================================
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ================================================================================
#
# Total Budget Items: 5686
# Total Budget Amount: ₦2,210,874,466,149
#
# Alignment Distribution:
#    NO: 2626 items (46.2%) | ₦628,172,564,174
#    YES: 2451 items (43.1%) | ₦1,331,965,056,587
#    PARTIAL: 609 items (10.7%) | ₦250,736,845,388
#
# 🚨 Items flagged as NOT aligned: 2626
#    Flagged amount: ₦628,172,564,174
#
# ====================================================================================================
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ====================================================================================================
#
# 🚨 ERGP12234386: ROADS REHABILITATION IN SELECTED LOCATIONS IN NORTH WEST, NI...
#    Agency: FEDERAL ROAD MAINTENANCE AGENCY
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
#    Reason: FERMA's mandate is limited to routine and periodic maintenance of existing federal roads, while road rehabilitation involves major reconstruction work that falls under the Federal Ministry of Works' capital projects mandate.
#
# 🚨 ERGP1246025: CONSTRUCTION OF POLICE TRAINING INSTITUTE (SHORT SERVICE) , ...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
#    Reason: The construction of a police training institute is completely outside the mandate of a cooperative college focused on training middle-level manpower for the cooperative subsector and related business disciplines.
#
# 🚨 ERGP27246215: CONSTRUCTION OF SCHOOL OF VETERINARY AND MEDICAL LABORATORY ...
#    Agency: FEDERAL COLLEGE OF VETERINARY AND MEDICAL LABORATORY TECHNOLOGY, VOM, PLATEAU STATE
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
#    Reason: The budget item is for construction in Kaduna State while the agency is specifically located in and operates from Plateau State, with no mandate indicating operations or facilities in Kaduna State.
#
# 🚨 ERGP27246215: CONSTRUCTION OF SCHOOL OF VETERINARY AND MEDICAL LABORATORY ...
#    Agency: FEDERAL COLLEGE OF VETERINARY AND MEDICAL LABORATORY TECHNOLOGY, VOM, PLATEAU STATE
#    Amount: ₦7,000,000,000
#    Confidence: HIGH
#    Reason: The budget item is for construction in Kaduna State while the agency is specifically located in and operates from Vom, Plateau State, with no mandate indicating multi-state operations or expansion authority.
#
# 🚨 ERGP30236268: PROVISION OF ACCESS ROADS AND EROSION CONTROL IN OKPORO, OHO...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- OJI RIVER
#    Amount: ₦6,500,000,000
#    Confidence: HIGH
#    Reason: The budget item involves infrastructure construction and erosion control across multiple states, which falls outside the college's mandate of providing cooperative education, training, and academic programs.
#
# 🚨 ERGP30234978: CONSTRUCTION OF LECTURE THEATERS, FACULTY BUILDINGS, HOSTELS...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- OJI RIVER
#    Amount: ₦6,500,000,000
#    Confidence: HIGH
#    Reason: The budget item specifies construction "in selected locations in Nigeria (multiple lots)" which extends beyond the Federal Co-operative College Oji River's specific institutional mandate and geographic scope as a single college facility.
#
# 🚨 ERGP30236268: PROVISION OF ACCESS ROADS AND EROSION CONTROL IN OKPORO, OHO...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- OJI RIVER
#    Amount: ₦6,500,000,000
#    Confidence: HIGH
#    Reason: The budget item involves infrastructure construction and erosion control across multiple states, which falls outside the educational mandate of a cooperative college that focuses on training and academic programs in cooperative studies and related fields.
#
# 🚨 ERGP12234394: REHABILITATION OF BUNI GARI-GULANI ROAD IN YOBE STATE.
# ...
#    Agency: FEDERAL ROAD MAINTENANCE AGENCY
#    Amount: ₦4,900,000,000
#    Confidence: HIGH
#    Reason: FERMA's mandate is limited to maintenance activities (routine, periodic, and emergency repairs) while rehabilitation involves major reconstruction work that falls under the Federal Ministry of Works' responsibility for road development and major rehabilitation projects.
#
# 🚨 ERGP1246072: CONSTRUCTION AND INSTALLATION OF ASTRAL ENERGY SYSTEMS FOR I...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The construction and installation of astral energy systems for illumination across the nation is a large-scale national infrastructure project that falls completely outside the mandate of an educational institution focused on cooperative training and related academic programs.
#
# 🚨 ERGP1246071: CONSTRUCTION AND DEVELOPMENT OF MODERN GENERAL HOSPITALS IN ...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The Federal Co-operative College Ibadan is an educational institution focused on training cooperative and business professionals, not a healthcare agency, and constructing hospitals falls entirely outside its educational mandate.
#
# 🚨 ERGP12234499: CONSTRUCTION OF GORGORAM - GURI ROAD IN YOBE STATE...
#    Agency: FEDERAL ROAD MAINTENANCE AGENCY
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: FERMA's mandate is limited to maintenance of existing federal roads, while construction of new roads like the Gorgoram-Guri road falls under the Federal Ministry of Works' construction responsibilities.
#
# 🚨 ERGP1246657: CONSTRUCTION OF EDUCATIONAL BUILDINGS IN SELECTED PUBLIC SCH...
#    Agency: FEDERAL COLLEGE OF LAND RESOURCES TECHNOLOGY - OWERRI
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The budget item involves constructing educational buildings in general public schools across the South West region, which falls outside FECOLART's specific mandate to train middle-level manpower in land resources technology, soil conservation, and environmental management through their own diploma programmes.
#
# 🚨 ERGP30236267: SUPPLY OF GRAINS, FERTILIZERS, CEREAL, HERBICIDES AND INSECT...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- OJI RIVER
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The Federal Co-operative College Oji River is an educational institution focused on training and curriculum delivery in cooperative studies and related disciplines, not direct agricultural input distribution to farmers.
#
# 🚨 ERGP1246472: SUPPLY OF GRAINS TO SELECTED VICTIMS OF INSURGENCIES, BANDIT...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- KADUNA
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: Supplying grains to victims of insurgencies, banditry, and domestic violence is a humanitarian relief activity that falls completely outside the Federal Co-operative College's educational mandate of providing cooperative training, education, and skills development programs.
#
# 🚨 ERGP25243407: "ESTABLISHMENT OF NATIONAL TARUMA CENTRE "...
#    Agency: FEDERAL MEDICAL CENTRE, AZARE BAUCHI
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The establishment of a National Taruma Centre falls outside the Federal Medical Centre Azare's mandate, which is focused on providing tertiary healthcare services, medical training, and research within the Bauchi State region rather than establishing national-level specialized centers.
#
# 🚨 ERGP1245688: SUPPLY OF PROCESSED AND SEMI-PROCESSED FOOD ITEMS TO VULNERA...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The agency's mandate focuses on training middle-level manpower for the cooperative sector and related academic programs, not on food supply or distribution to vulnerable communities.
#
# 🚨 ERGP1245615: CONSTRUCTION OF RURAL ROADS & RURAL MARKETS IN SELECTED LOCA...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: Construction of rural roads and markets is infrastructure development work that falls outside the educational mandate of a cooperative college focused on training students and supporting cooperative societies through academic programs and capacity building.
#
# 🚨 ERGP30236267: SUPPLY OF GRAINS, FERTILIZERS, CEREAL, HERBICIDES AND INSECT...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- OJI RIVER
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: The budget item involves direct supply of agricultural inputs to farmers, which falls outside the college's mandate as an educational institution focused on cooperative studies, business, and technical education rather than agricultural supply operations.
#
# 🚨 ERGP1245961: PROVISION OF TRICYCLES AND MOTOR CYCLES FOR POVERTY ALLEVIAT...
#    Agency: FEDERAL CO-OPERATIVE COLLEGE- IBADAN
#    Amount: ₦2,870,000,000
#    Confidence: HIGH
#    Reason: The Federal Co-operative College Ibadan's mandate is focused on education and training for the cooperative sector, not direct poverty alleviation through distribution of vehicles across geo-political zones.
#
# 🚨 ERGP12246349: CONSTRUCTION & REHABILITATION OF SOME SELECTED RURAL FARM RO...
#    Agency: FEDERAL COLLEGE OF VETERINARY AND MEDICAL LABORATORY TECHNOLOGY, VOM, PLATEAU STATE
#    Amount: ₦2,835,000,000
#    Confidence: HIGH
#    Reason: The construction and rehabilitation of rural farm roads is not within the mandate of this veterinary and medical laboratory technology college, which is specifically focused on training technicians and technologists in animal health, production, and veterinary laboratory services.

# %%
result_df.columns.to_list()
# Out:
# ['code',
#  'ergp_line_item',
#  'mda_code',
#  'agency',
#  'mother_ministry',
#  'amount',
#  'alignment',
#  'confidence',
#  'reason',
#  'mandate_deviation_score']

# %%
# Calculate total
total = result_df['amount'].sum()
total_formatted = f"Total: ₦{total:,.2f}"

# A: Sum amount where alignment is NO
flagged = result_df[result_df["alignment"] == "NO"]
flagged_amount = flagged['amount'].sum()
flagged_amount_naira = f"₦{flagged_amount:.2f}"
# B: Sum amount for full filtered dataframe
total_mda_project_value = f"₦{total:.2f}"
# C: A/B
flagged_percentage = flagged_amount/total
# Format the output as a percentage with 2 decimal places
format_flagged_as_percent = f"{flagged_percentage:.2%}"

# %%
total_mda_project_value
# Out:
# '₦2210874466149.00'

# %%
format_flagged_as_percent
# Out:
# '28.41%'

# %%
flagged_amount_naira
# Out:
# '₦628172564174.00'

# %%
mandate_deviation_output_path_1_50 = "data/outputs/mandate_deviation/llm_alignment_results_1_to_50.csv"
result_df_1_50 = pd.read_csv(mandate_deviation_output_path_1_50)

# %%
print(len(result_df_1_50))
# Out:
# 2355

# %%
# Calculate total
total = result_df['amount'].sum()
total_formatted = f"Total: ₦{total:,.2f}"

# A: Sum amount where alignment is NO
flagged = result_df[result_df["alignment"] == "NO"]
flagged_amount = flagged['amount'].sum()
flagged_amount_naira = f"₦{flagged_amount:.2f}"
# B: Sum amount for full filtered dataframe
total_mda_project_value = f"₦{total:.2f}"
# C: A/B
flagged_percentage = flagged_amount/total
# Format the output as a percentage with 2 decimal places
format_flagged_as_percent = f"{flagged_percentage:.2%}"

# %%
flagged_amount_naira
# Out:
# '₦144628302649.00'

# %%
# 3. View results
print_summary_llm(result_df_1_50)
print_flagged_items_llm(result_df_1_50)


pass
# Out:
# ================================================================================
# SUMMARY: LLM-AS-JUDGE ANALYSIS
# ================================================================================
#
# Total Budget Items: 2355
# Total Budget Amount: ₦780,536,740,991
#
# Alignment Distribution:
#    YES: 1261 items (53.5%) | ₦208,782,504,556
#    NO: 812 items (34.5%) | ₦144,628,302,649
#    PARTIAL: 282 items (12.0%) | ₦427,125,933,786
#
# 🚨 Items flagged as NOT aligned: 812
#    Flagged amount: ₦144,628,302,649
#
# ====================================================================================================
# TOP 20 FLAGGED ITEMS (NOT ALIGNED)
# ====================================================================================================
#
# 🚨 ERGP16234836: "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT HEADQUARTER OFF...
#    Agency: BUREAU OF PUBLIC ENTERPRISES (BPE)
#    Amount: ₦14,000,000,000
#    Confidence: HIGH
#    Reason: The budget item refers to acquiring headquarters for the Bureau of Public Procurement, which is a completely different agency from the Bureau of Public Enterprises and falls outside BPE's mandate of privatisation and commercialisation.
#
# 🚨 ERGP22242227: COMPLETION AND EQUIPPING OF GENERAL HOSPITALS (MULTIPLE LOTS...
#    Agency: AMINU KANO UNIVERSITY TEACHING HOSPITAL
#    Amount: ₦4,200,000,000
#    Confidence: HIGH
#    Reason: The budget item involves completion and equipping of general hospitals in Bagwai LGA, which falls outside AKTH's mandate as a teaching hospital focused on tertiary care, medical education, and research rather than establishing or equipping general hospitals in local government areas.
#
# 🚨 ERGP1246874: PROVISION OF FARM IMPLEMENTS AND FERTILIZER TO VULNERABLE CO...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦3,500,000,000
#    Confidence: HIGH
#    Reason: ARCN's mandate is focused on research, training, and extension coordination rather than direct provision of farm implements and fertilizers to communities, which would be an implementation/operational activity outside their supervisory and coordinating role.
#
# 🚨 ERGP25242209: EQUIPPING OF MUHAMMAD ABDULLAHI WASE SPECIALIST HOSPITAL (MU...
#    Agency: AMINU KANO UNIVERSITY TEACHING HOSPITAL
#    Amount: ₦2,100,000,000
#    Confidence: HIGH
#    Reason: This budget item is for equipping a different hospital (Muhammad Abdullahi Wase Specialist Hospital) rather than Aminu Kano University Teaching Hospital itself, which falls outside AKTH's institutional mandate.
#
# 🚨 ERGP1246853: CONSTRUCTION OF SELECTED INNER RURAL ROADS AND SOLAR STREET ...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,554,700,000
#    Confidence: HIGH
#    Reason: Construction of rural roads and solar street lights is infrastructure development work that falls outside ARCN's mandate which is specifically focused on agricultural research, training, extension activities, and coordination of agricultural science institutions.
#
# 🚨 ERGP1247024: CONSTRUCTION OF SCHOOL IN DIFFERENT COMMUNITIES IN OGUN STAT...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Construction of general schools to discourage out-of-school children falls under basic education mandate, not agricultural research, training, and extension activities which are ARCN's core functions.
#
# 🚨 ERGP1247025: CONSTRUCTION OF RURAL FARM ROADS IN SELECTED COMMUNITIES OF ...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: ARCN's mandate focuses on agricultural research, training, extension coordination, and supervision of research institutes, but does not include infrastructure construction like farm roads, which falls outside their core functions of research coordination and policy advisory roles.
#
# 🚨 ERGP1246980: EMPOWERMENT OF YOUTH AND WOMEN IN FOOTWEAR AND LEATHER GOODS...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: This budget item focuses on footwear and leather goods manufacturing empowerment, which falls outside ARCN's mandate that is specifically limited to agricultural research, training, and extension activities.
#
# 🚨 ERGP1246907: GADING AND ASPHALTING OF SELECTED RURAL FARMING ROAD IN LAGO...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Road grading and asphalting is infrastructure construction work that falls outside ARCN's mandate which focuses specifically on agricultural research, training, extension activities, and coordination of research institutes rather than physical infrastructure development.
#
# 🚨 ERGP1246905: RECONSTRUCTION OF SELECTED DILAPIDATED FARMERS ACCESS ROADS ...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Road reconstruction falls outside ARCN's mandate which focuses specifically on agricultural research, training, extension coordination, and supervision of research institutes rather than infrastructure development or road construction projects.
#
# 🚨 ERGP1246907: GADING AND ASPHALTING OF SELECTED RURAL FARMING ROAD IN LAGO...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Road grading and asphalting is infrastructure construction work that falls outside ARCN's mandate which focuses specifically on agricultural research, training, extension activities, and coordination of research institutes rather than physical infrastructure development.
#
# 🚨 ERGP1246905: RECONSTRUCTION OF SELECTED DILAPIDATED FARMERS ACCESS ROADS ...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Road reconstruction is infrastructure development that falls outside ARCN's mandate which specifically focuses on agricultural research, training, extension activities, and coordination of research institutes rather than physical infrastructure projects.
#
# 🚨 ERGP1247023: CONSTRUCTION OF MARKET STALLS IN RURAL FARMING COMMUNITIES A...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,400,000,000
#    Confidence: HIGH
#    Reason: Construction of market stalls is infrastructure development outside ARCN's mandate, which focuses specifically on coordinating agricultural research, training, and extension activities rather than building commercial infrastructure.
#
# 🚨 ERGP23236312: ACQUISITION AND LAND CLEARING FOR UNIVERSITY OF SCIENCE AND ...
#    Agency: BENIN/ OWENA RBDA
#    Amount: ₦1,190,000,000
#    Confidence: HIGH
#    Reason: Acquiring and clearing land for a university in Lagos State falls completely outside BORBDA's mandate, which is specifically focused on water resources development and management within the Benin-Owena River Basin covering Edo, Ondo, Ekiti states and one senatorial district in Delta State.
#
# 🚨 ERGP1247022: GRADING/ASPHALTING OF FARM SETTLEMENT ROAD WITH DRAINAGE CON...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,050,000,000
#    Confidence: HIGH
#    Reason: Road construction and infrastructure development falls outside ARCN's mandate which focuses on coordinating agricultural research, training, and extension activities rather than physical infrastructure projects.
#
# 🚨 ERGP1246906: INSTALLATION OF MOTORIZED BOREHOLE WITH OVERHEAD TANK IN SEL...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,050,000,000
#    Confidence: HIGH
#    Reason: Installing motorized boreholes with overhead tanks in communities is a water infrastructure development activity that falls outside ARCN's mandate, which is specifically focused on agricultural research, training, and extension activities rather than community water supply projects.
#
# 🚨 ERGP1246906: INSTALLATION OF MOTORIZED BOREHOLE WITH OVERHEAD TANK IN SEL...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,050,000,000
#    Confidence: HIGH
#    Reason: Installing motorized boreholes with overhead tanks in communities is a water infrastructure project that falls outside ARCN's mandate, which specifically focuses on agricultural research, training, and extension activities rather than community water supply infrastructure.
#
# 🚨 ERGP1246909: CONSTRUCTION AND TARRING (WITH ASPHALT) OF DADINKOWA - MAGAN...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,050,000,000
#    Confidence: HIGH
#    Reason: Road construction and tarring falls outside ARCN's mandate which is specifically focused on agricultural research, training, extension activities, and coordination of agricultural research institutes rather than infrastructure development.
#
# 🚨 ERGP1246909: CONSTRUCTION AND TARRING (WITH ASPHALT) OF DADINKOWA - MAGAN...
#    Agency: AGRICULTURAL RESEARCH COUNCIL OF NIGERIA
#    Amount: ₦1,050,000,000
#    Confidence: HIGH
#    Reason: Road construction and tarring falls under infrastructure development which is outside ARCN's mandate that specifically focuses on agricultural research, training, extension activities, and coordination of agricultural institutes.
#
# 🚨 ERGP25247721: SUPPLY OF FURNITURE AND EQUIPMENT FOR SCHOOL OF BIOMEDICAL E...
#    Agency: ABUBAKAR TAFAWA BALEWA UNIVERSITY TEACHING HOSPITAL BAUCHI
#    Amount: ₦1,000,000,000
#    Confidence: HIGH
#    Reason: The budget item is for a School of Biomedical Engineering, but ATBUTH is a teaching hospital affiliated with a College of Medical Sciences that focuses on clinical training, healthcare delivery, and medical research, not biomedical engineering education.

# %%
print(len(result_df_1_50))
# Out:
# 2355

# %%
mandate_deviation_output_path_51_200 = "data/outputs/mandate_deviation/llm_alignment_results_51_to_200.csv"
result_df_51_200 = pd.read_csv(mandate_deviation_output_path_51_200)

# %%
print(len(result_df_51_200))
# Out:
# 5686

# %%
# Merge vertically (stack rows)
merged_mandate_deviation_for_mdas_1_200_df = pd.concat([result_df_1_50, result_df_51_200], ignore_index=True)

# %%
print(len(merged_mandate_deviation_for_mdas_1_200_df))
# Out:
# 8041

# %%
cols = ['code', 'ergp_line_item', 'mda_code', 'amount']

# %%
duplicates = merged_mandate_deviation_for_mdas_1_200_df[merged_mandate_deviation_for_mdas_1_200_df.duplicated(subset=cols)]

# %%
duplicates.head()
# Out:
#              code                                     ergp_line_item  \
# 800  ERGP30242140  CONSTRUCTION OF AL-QUAREEB COMMUNITY MOSQUE AN...
# 801  ERGP30242141  RENOVATION OF SCHOOLS IN IBARAPA EAST/IDO FEDE...
# 802  ERGP30242143  CONSTRUCTION OF WELL EQUIPPED I.C.T CENTER IN ...
# 803  ERGP30242145  PROVISION OF MOTORISED BOREHOLE ACROSS OGO-OLU...
# 804  ERGP30242146  PROVISION OF ALL IN ONE SOLAR POWERED STREETLI...
#
#       mda_code                            agency  mother_ministry  \
# 800  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 801  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 802  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 803  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
# 804  215014001  COCOA RESEARCH INSTITUTE- IBADAN              NaN
#
#           amount alignment confidence  \
# 800  280000000.0        NO       HIGH
# 801  140000000.0        NO       HIGH
# 802  175000000.0        NO       HIGH
# 803  140000000.0        NO       HIGH
# 804  140000000.0        NO       HIGH
#
#                                                 reason  \
# 800  Construction of a mosque, palace, and provisio...
# 801  The renovation of schools falls under educatio...
# 802  The construction of an ICT center in a specifi...
# 803  Providing motorized boreholes across a specifi...
# 804  Installing solar streetlights in federal const...
#
#      mandate_deviation_score
# 800                      100
# 801                      100
# 802                      100
# 803                      100
# 804                      100

# %%
print(len(duplicates))
# Out:
# 235

# %%
merged_mandate_deviation_for_mdas_1_200_df_no_duplicates = merged_mandate_deviation_for_mdas_1_200_df.drop_duplicates(subset=cols)

# %%
merged_mandate_deviation_for_mdas_1_200_df_no_duplicates.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# 0       YES       HIGH  IT infrastructure and associated equipment dir...
# 1       YES       HIGH  Office furniture and fittings are necessary ad...
# 2       YES       HIGH  Purchasing computers for staff official use is...
# 3   PARTIAL     MEDIUM  While the remodeling of BPE's main entrance do...
# 4        NO       HIGH  The budget item refers to acquiring headquarte...
#
#    mandate_deviation_score
# 0                        0
# 1                        0
# 2                        0
# 3                       50
# 4                      100

# %%
df = merged_mandate_deviation_for_mdas_1_200_df_no_duplicates.reset_index(drop=True)

# %%
mandate_deviation_output_path_1_200 = "data/outputs/mandate_deviation/llm_alignment_results_1_to_200_combined.csv"
df.to_csv(mandate_deviation_output_path_1_200, index=False)

# %%
df.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# 0       YES       HIGH  IT infrastructure and associated equipment dir...
# 1       YES       HIGH  Office furniture and fittings are necessary ad...
# 2       YES       HIGH  Purchasing computers for staff official use is...
# 3   PARTIAL     MEDIUM  While the remodeling of BPE's main entrance do...
# 4        NO       HIGH  The budget item refers to acquiring headquarte...
#
#    mandate_deviation_score
# 0                        0
# 1                        0
# 2                        0
# 3                       50
# 4                      100

# %%
street_light_list = ['STREET LIGHT', 'streetlight', 'street lights', 'streetlights']
# Filter the DataFrame
street_lights_df = df[df['ergp_line_item'].isin(street_light_list)]

# street_lights_df = df[df['ergp_line_item'].str.lower().isin(street_light_list)]



# List of keywords to check
# keywords = ['test', 'test2']

# Create a regular expression pattern by joining the keywords with '|'
pattern = '|'.join(street_light_list)

# Filter the DataFrame for rows where any keyword occurs in the column
street_lights_df = df[df['ergp_line_item'].str.contains(pattern, case=False, na=False)]

# print(street_lights_df)
# Out:
#               code                                     ergp_line_item  \
# 40    ERGP10225206  SOLAR STREET LIGHT SYSTEM FOR ACADEMIC AREAS A...
# 128   ERGP10236498  THREE-IN-ONE SOLAR STREET LIGHT IN OGBARU FEDE...
# 129   ERGP10236499  PROVISION OF SOLAR STREET LIGHT IN ALIERO/GWAN...
# 130   ERGP10236500  PROVISION OF SOLAR STREET LIGHT IN GORONYO/GAD...
# 132   ERGP10236527  PROVISION AND INSTALATION OF STREETLIGHTS IN K...
# ...            ...                                                ...
# 7310  ERGP25242158  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7312  ERGP25242166  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7409  ERGP25226606                 PROVISION OF SOLAR STREET LIGHTS\n
# 7628  ERGP25240706  SUPPLY AND INSTALLATION OF SOLAR POWERED STREE...
# 7711  ERGP10224538  REHABILITATION/INSTALLATION OF STREET LIGHTS A...
#
#        mda_code                                             agency  \
# 40    116008001                    COMMAND AND STAFF COLLEGE, JAJI
# 128   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 129   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 130   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 132   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# ...         ...                                                ...
# 7310  521027017                    FEDERAL MEDICAL CENTRE, UMUAHIA
# 7312  521027017                    FEDERAL MEDICAL CENTRE, UMUAHIA
# 7409  521027024                 FEDERAL MEDICAL CENTRE, NGURU YOBE
# 7628  521027038                FEDERAL MEDICAL CENTRE, EBUTE METTA
# 7711  521027058      FEDERAL MEDICAL CENTRE ONITSHA, ANAMBRA STATE
#
#       mother_ministry       amount alignment confidence  \
# 40                NaN  101563700.0       YES       HIGH
# 128               NaN   21000000.0        NO       HIGH
# 129               NaN   14000000.0       YES       HIGH
# 130               NaN   14000000.0       YES       HIGH
# 132               NaN   35000000.0        NO       HIGH
# ...               ...          ...       ...        ...
# 7310              NaN  105000000.0        NO       HIGH
# 7312              NaN  105000000.0        NO       HIGH
# 7409              NaN    7000000.0   PARTIAL     MEDIUM
# 7628              NaN   21000000.0        NO       HIGH
# 7711              NaN   10500000.0       YES       HIGH
#
#                                                  reason  \
# 40    Solar street lighting for academic areas and s...
# 128   Ogbaru Federal Constituency in Anambra State i...
# 129   This budget item aligns with BCDA's mandate to...
# 130   Providing solar street lights in border consti...
# 132   The budget item targets a federal constituency...
# ...                                                 ...
# 7310  Installing solar street lights in various loca...
# 7312  Installing solar street lights across multiple...
# 7409  Solar street lights can support the medical ce...
# 7628  Installing solar street lights in Kwara State ...
# 7711  Installing street lights at the hospital direc...
#
#       mandate_deviation_score
# 40                          0
# 128                       100
# 129                         0
# 130                         0
# 132                       100
# ...                       ...
# 7310                      100
# 7312                      100
# 7409                       50
# 7628                      100
# 7711                        0
#
# [731 rows x 10 columns]

# %%
street_lights_df
# Out:
#               code                                     ergp_line_item  \
# 40    ERGP10225206  SOLAR STREET LIGHT SYSTEM FOR ACADEMIC AREAS A...
# 128   ERGP10236498  THREE-IN-ONE SOLAR STREET LIGHT IN OGBARU FEDE...
# 129   ERGP10236499  PROVISION OF SOLAR STREET LIGHT IN ALIERO/GWAN...
# 130   ERGP10236500  PROVISION OF SOLAR STREET LIGHT IN GORONYO/GAD...
# 132   ERGP10236527  PROVISION AND INSTALATION OF STREETLIGHTS IN K...
# ...            ...                                                ...
# 7310  ERGP25242158  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7312  ERGP25242166  PROVISION OF ALL IN ONE SOLAR STREET LIGHTS IN...
# 7409  ERGP25226606                 PROVISION OF SOLAR STREET LIGHTS\n
# 7628  ERGP25240706  SUPPLY AND INSTALLATION OF SOLAR POWERED STREE...
# 7711  ERGP10224538  REHABILITATION/INSTALLATION OF STREET LIGHTS A...
#
#        mda_code                                             agency  \
# 40    116008001                    COMMAND AND STAFF COLLEGE, JAJI
# 128   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 129   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 130   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# 132   161022001  BORDER COMMUNITIES DEVELOPMENT AGENCY (BCDA) H...
# ...         ...                                                ...
# 7310  521027017                    FEDERAL MEDICAL CENTRE, UMUAHIA
# 7312  521027017                    FEDERAL MEDICAL CENTRE, UMUAHIA
# 7409  521027024                 FEDERAL MEDICAL CENTRE, NGURU YOBE
# 7628  521027038                FEDERAL MEDICAL CENTRE, EBUTE METTA
# 7711  521027058      FEDERAL MEDICAL CENTRE ONITSHA, ANAMBRA STATE
#
#       mother_ministry       amount alignment confidence  \
# 40                NaN  101563700.0       YES       HIGH
# 128               NaN   21000000.0        NO       HIGH
# 129               NaN   14000000.0       YES       HIGH
# 130               NaN   14000000.0       YES       HIGH
# 132               NaN   35000000.0        NO       HIGH
# ...               ...          ...       ...        ...
# 7310              NaN  105000000.0        NO       HIGH
# 7312              NaN  105000000.0        NO       HIGH
# 7409              NaN    7000000.0   PARTIAL     MEDIUM
# 7628              NaN   21000000.0        NO       HIGH
# 7711              NaN   10500000.0       YES       HIGH
#
#                                                  reason  \
# 40    Solar street lighting for academic areas and s...
# 128   Ogbaru Federal Constituency in Anambra State i...
# 129   This budget item aligns with BCDA's mandate to...
# 130   Providing solar street lights in border consti...
# 132   The budget item targets a federal constituency...
# ...                                                 ...
# 7310  Installing solar street lights in various loca...
# 7312  Installing solar street lights across multiple...
# 7409  Solar street lights can support the medical ce...
# 7628  Installing solar street lights in Kwara State ...
# 7711  Installing street lights at the hospital direc...
#
#       mandate_deviation_score
# 40                          0
# 128                       100
# 129                         0
# 130                         0
# 132                       100
# ...                       ...
# 7310                      100
# 7312                      100
# 7409                       50
# 7628                      100
# 7711                        0
#
# [731 rows x 10 columns]

# %%
street_light_total = street_lights_df['amount'].sum()
print(street_light_total/1000000000)
# Out:
# 118.242932783

# %%
df.head()
# Out:
#            code                                     ergp_line_item   mda_code  \
# 0   ERGP1102191       IT INFRASTRUCTURE AND ASSOCIATED EQUIPMENT\n  111007001
# 1   ERGP1102209  PURCHASE OF OFFICE FURNITURE AND FITTINGS FOR ...  111007001
# 2   ERGP1205869  PURCHASE OF LAP TOP AND DESKTOP COMPUTERS FOR ...  111007001
# 3   ERGP1205905  REMODELING OF SECURITY HOUSE AND BPE MAIN ENTR...  111007001
# 4  ERGP16234836  "ACQUISITION OF BUREAU OF PUBLIC PROCUREMENT H...  111007001
#
#                                agency  mother_ministry        amount  \
# 0  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  9.817500e+07
# 1  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.490738e+07
# 2  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.107260e+08
# 3  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+07
# 4  BUREAU OF PUBLIC ENTERPRISES (BPE)              NaN  1.400000e+10
#
#   alignment confidence                                             reason  \
# 0       YES       HIGH  IT infrastructure and associated equipment dir...
# 1       YES       HIGH  Office furniture and fittings are necessary ad...
# 2       YES       HIGH  Purchasing computers for staff official use is...
# 3   PARTIAL     MEDIUM  While the remodeling of BPE's main entrance do...
# 4        NO       HIGH  The budget item refers to acquiring headquarte...
#
#    mandate_deviation_score
# 0                        0
# 1                        0
# 2                        0
# 3                       50
# 4                      100

# %%
print(len(street_lights_df['mda_code'].unique()))
# Out:
# 44
